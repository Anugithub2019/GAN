# %% [markdown]
# # Number of Intrinsic Dimensions (for Real Data)

# %%
DATA = "../GAN_exp_dog"

# %%
def cat(f):
     with open(f) as f:
         print(f.read())

# %%
cat(f"{DATA}/intrinsic_dim_real.txt")
# Out:
# Intrinsic Dimension of real data: [24.82] Standard error: 0.0

# %%
#ChatGPT generated code block to extract the intrinsic dims from the above file

import re

def extract_intrinsic_dimension(input_string):
    # Define a regular expression pattern to match the intrinsic dimension
    pattern = r'Intrinsic Dimension of real data:\s*([\d.]+)'

    # Use re.search to find the match in the input string
    match = re.search(pattern, input_string)

    if match:
        # Extract the intrinsic dimension from the matched group
        intrinsic_dimension = float(match.group(1))
        return intrinsic_dimension
    else:
        # Return None if the pattern is not found
        return None

# Example usage
input_string = "Intrinsic Dimension of real data: 23.442501263446754 Standard error: 0.0"
real_intrinsic_dim = extract_intrinsic_dimension(input_string)

print("Intrinsic Dimension:", real_intrinsic_dim)
# Out:
# Intrinsic Dimension: 23.442501263446754

# %% [markdown]
# # Number of Intrinsic Dimensions (for Generated Data)

# %%
cat(f"{DATA}/intrinsic_dim.csv")
# Out:
# epoch,intrinsic_dim,err1
# 9,8.332706570434581,0.0
# 19,10.961193793409171,0.0
# 29,13.214391169296773,0.0
# 39,13.055877307312262,0.0
# 49,13.510165610214717,0.0
# 59,14.389388824592848,0.0
# 69,15.865825536182381,0.0
# 79,16.10105052228996,0.0
# 89,16.61713758345326,0.0
# 99,17.427146635504798,0.0
# 109,19.061943124931386,0.0
# 119,22.63724255551823,0.0
# 129,23.46722740190927,0.0
# 139,22.919103742967792,0.0
# 149,22.44680343962651,0.0
# 159,21.287978826355438,0.0
# 169,24.433515894562273,0.0
# 179,24.497779521084922,0.0
# 189,23.95262854424091,0.0
# 199,23.983369933256373,0.0
# 209,23.767290361867982,0.0
# 219,24.575046662552417,0.0
# 229,24.8768583665754,0.0
# 239,22.96080230527329,0.0
# 249,26.20633611074302,0.0
# 259,22.965303283596274,0.0
# 269,23.17407799411771,0.0
# 279,24.466669247489527,0.0
# 289,22.58433911845199,0.0
# 299,24.498175934928973,0.0
# 309,25.224551983075667,0.0
# 319,24.014832294665027,0.0
# 329,25.00249385047316,0.0
# 339,25.21639647271443,0.0
# 349,24.88904935583112,0.0
# 359,24.63554558589883,0.0
# 369,22.12276625598452,0.0
# 379,22.655373226624604,0.0
# 389,24.93673783857302,0.0
# 399,24.301216461822378,0.0
# 409,25.135092842052828,0.0
# 419,25.53602467418979,0.0
# 429,23.03792135682142,0.0
# 439,23.918714608612348,0.0
# 449,23.74955108684198,0.0
# 459,25.622561770571156,0.0
# 469,23.901152880490358,0.0
# 479,24.534918829179805,0.0
# 489,23.104639948689535,0.0
# 499,24.16380407803553,0.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the CSV file using pandas
df = pd.read_csv(f'{DATA}/intrinsic_dim.csv')

# Create a plot using seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Plot the data for intrinsic dimensions of generated data
sns.lineplot(x='epoch', y='intrinsic_dim', data=df, marker='o', linestyle='-', label='Intrinsic Dimensions of Generated Data', color='b')

# Add a horizontal line for intrinsic dimensions of real data
plt.axhline(y=real_intrinsic_dim, color='r', linestyle='--', label=f'Intrinsic Dimensions of Real Data ({real_intrinsic_dim:.2f})')

# Set plot labels and title
plt.xlabel('Epoch')
plt.ylabel('Intrinsic Dimensions')
#plt.title('Intrinsic Dimension as a Function of Epoch')

plt.xlim(0, 500)
plt.ylim(0, 30)

# Add a legend
plt.legend(loc='lower right')

# Show the plot
plt.show()
